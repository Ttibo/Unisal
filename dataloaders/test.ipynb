# %%
import importlib
import VideoDatasetV2
importlib.reload(VideoDatasetV2)
import random

salicon_ = VideoDatasetV2.VideoDatasetV2(N = 10,  path="/Users/coconut/Documents/Dataset/GenSaliency/VisualSaliency/Ittention_videos_advertising/train/")

# show output from dataloader
print("Dataloader Salicon" , len(salicon_))
img, sal, fix, _ = salicon_[1009]

print(img.shape)
print(sal.shape)
print(fix.shape)
# print(target_size)

import torch
import matplotlib.pyplot as plt
import torchvision.transforms as T


def show_images(tensor):
    # Vérifie que le tenseur a bien la forme attendue
    assert tensor.shape == (10, 3, 256, 416), "Le tenseur doit être de la forme torch.Size([10, 3, 256, 416])"
    
    # Convertit les images en format acceptable pour matplotlib (de [C, H, W] à [H, W, C])
    to_pil_image = T.ToPILImage()
    
    # Crée une figure avec une seule ligne et 10 colonnes pour afficher les images
    fig, axs = plt.subplots(1, 10, figsize=(20, 5))
    
    # Parcours et affiche les 10 images
    for i in range(10):
        ax = axs[i]                    # Sélectionne la sous-figure
        ax.imshow(tensor[i].permute(1,2,0))                 # Affiche l'image
        ax.axis('off')                 # Désactive les axes

    plt.show()
show_images(img)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.117904..2.64].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.117904..2.64].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.117904..2.64].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.117904..2.64].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.117904..2.64].
# Path: /Users/coconut/Documents/Dataset/GenSaliency/VisualSaliency/Ittention_videos_advertising/train/
# Numbers videos 59
# Dataloader Salicon 9206
# torch.Size([10, 3, 256, 416])
# torch.Size([10, 1, 256, 416])
# torch.Size([10, 1, 256, 416])
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.117904..2.64].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.117904..2.64].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.117904..2.64].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.117904..2.64].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.117904..2.64].
