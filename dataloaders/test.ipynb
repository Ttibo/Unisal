# %%
import importlib
import Salicon
importlib.reload(Salicon)
import random

salicon_ = Salicon.SALICONDataset(phase='train' , path="/Users/thibaultlelong/Documents/Dataset/GenSaliency/VisualSaliency/SALICON/")

# show output from dataloader
print("Dataloader Salicon" , len(salicon_))
img, sal, fix, target_size = salicon_[random.randint(0 , len(salicon_))]

print(img.shape)
print(sal.shape)
print(fix.shape)
print(target_size)

import numpy as np
tensor = np.transpose(img, (1, 2, 0))
tensor1 = np.transpose(sal, (1, 2, 0))
tensor2 = np.transpose(fix, (1, 2, 0))

import matplotlib.pyplot as plt
plt.figure(figsize= (20 , 10))

plt.subplot(1, 3, 1)

plt.imshow(tensor)
plt.title('Image')

plt.subplot(1, 3, 2)  
plt.imshow(tensor1)
plt.title('saliency')

plt.subplot(1, 3, 3)  
plt.imshow(tensor2)
plt.title('Fixation')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.0665298..2.64].
# Samples Salicon  101
# Dataloader Salicon 101
# torch.Size([3, 288, 384])
# torch.Size([1, 480, 640])
# torch.Size([1, 480, 640])
# (480, 640)
# Text(0.5, 1.0, 'Fixation')

# %%
import MIT10003
importlib.reload(MIT10003)

mit10003_ = MIT10003.MIT1003Dataset(phase='train' , path="/Users/thibaultlelong/Documents/Dataset/GenSaliency/VisualSaliency/Packaging/")


# show output from dataloader
print("Dataloader mit10003_" , len(mit10003_))
img, sal, fix, target_size = mit10003_[random.randint(0 , len(mit10003_))]

print(img.shape)
print(sal.shape)
print(fix.shape)
print(target_size)

import numpy as np
tensor = np.transpose(img, (1, 2, 0))
tensor1 = np.transpose(sal, (1, 2, 0))
tensor2 = np.transpose(fix, (1, 2, 0))

import matplotlib.pyplot as plt
plt.figure(figsize= (20 , 10))

plt.subplot(1, 3, 1)

plt.imshow(tensor)
plt.title('Image')

plt.subplot(1, 3, 2)  
plt.imshow(tensor1)
plt.title('saliency')

plt.subplot(1, 3, 3)  
plt.imshow(tensor2)
plt.title('Fixation')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.117904..2.64].
# config_path  /Users/thibaultlelong/Documents/GenSaliency/Ittention-Unisal/src/saliency/dataloaders/cache
# X-Val step: 0
# test image dir:  /Users/thibaultlelong/Documents/Dataset/GenSaliency/VisualSaliency/Packaging/images
# Dataloader mit10003_ 45
# torch.Size([3, 416, 288])
# torch.Size([1, 832, 576])
# torch.Size([1, 832, 576])
# (832, 576)
# Text(0.5, 1.0, 'Fixation')
