# %%
import importlib
import VideoDataset
importlib.reload(VideoDataset)
import random

import torch
import matplotlib.pyplot as plt
import torchvision.transforms as T


def show_images(tensor):
    # Vérifie que le tenseur a bien la forme attendue
    # Convertit les images en format acceptable pour matplotlib (de [C, H, W] à [H, W, C])
    to_pil_image = T.ToPILImage()
    
    # Crée une figure avec une seule ligne et 10 colonnes pour afficher les images
    fig, axs = plt.subplots(1, tensor.shape[0], figsize=(20, 5))
    
    # Parcours et affiche les 10 images
    for i in range(tensor.shape[0]):
        ax = axs[i]                    # Sélectionne la sous-figure
        ax.imshow(tensor[i].permute(1,2,0))                 # Affiche l'image
        ax.axis('off')                 # Désactive les axes

    plt.show()


dhf1k_ = VideoDataset.VideoDataset(  path="/Users/coconut/Documents/Dataset/GenSaliency/VisualSaliency/DHF1K/DHF1K/")

# show output from dataloader
print("Dataloader Salicon" , len(dhf1k_))
for i in range(0 , len(dhf1k_)):
    img, sal, fix, _ = dhf1k_[i]

print(img.shape)
print(sal.shape)
print(fix.shape)
# print(target_size)

show_images(img)
# Out:
# Number video 85
# Dataloader Salicon 85
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.117904..2.64].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.117904..2.64].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.117904..2.64].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.117904..2.64].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.117904..2.64].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.117904..2.64].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.117904..2.64].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.117904..2.64].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.117904..2.64].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.117904..2.64].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.117904..2.64].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.117904..2.64].
# torch.Size([12, 3, 256, 416])
# torch.Size([12, 1, 256, 416])
# torch.Size([12, 1, 256, 416])

# %%
ittention_vid_ = VideoDataset.VideoDataset(
    path="/Users/coconut/Documents/Dataset/GenSaliency/VisualSaliency/Ittention_advertising_video/",
    img_dir="frames"
    
    )

# show output from dataloader
print("Dataloader " , len(ittention_vid_))
for i in range(0 , len(ittention_vid_)):
    img, sal, fix, _ = ittention_vid_[i]

print(img.shape)
print(sal.shape)
print(fix.shape)
# print(target_size)

show_images(img)
# Out:
# Number video 56
# Dataloader  56
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.9831933..2.64].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.9831933..2.64].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.0007002..2.64].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.0007002..2.64].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.0357141..2.5179958].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.0182073..2.5179958].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.0357141..2.5179958].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.0836544..2.64].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.8952821..2.64].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.8044444..2.64].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.8044444..2.64].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.8081232..2.64].
# torch.Size([12, 3, 256, 416])
# torch.Size([12, 1, 256, 416])
# torch.Size([12, 1, 256, 416])

# %%
import Salicon
importlib.reload(Salicon)

salicon_train = Salicon.SALICONDataset(path ="/Users/coconut/Documents/Dataset/GenSaliency/VisualSaliency/SALICON/", phase="train", limit=50 )


# show output from dataloader
print("Dataloader " , len(salicon_train))
for i in range(0 , len(salicon_train)):
    img, sal, fix, _ = salicon_train[i]

print(img.shape)
print(sal.shape)
print(fix.shape)
# print(target_size)

fig, axs = plt.subplots(1, 3, figsize=(20, 5))

ax = axs[0]                    # Sélectionne la sous-figure
ax.imshow(img.permute(1,2,0))                 # Affiche l'image
ax.axis('off')   

ax = axs[1]                    # Sélectionne la sous-figure
ax.imshow(sal.permute(1,2,0))                 # Affiche l'image
ax.axis('off')   

ax = axs[2]                    # Sélectionne la sous-figure
ax.imshow(fix.permute(1,2,0))                 # Affiche l'image
ax.axis('off')
# Out:
# Salicon size :  50
# Dataloader  50
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.117904..2.3410363].
# torch.Size([3, 288, 384])
# torch.Size([1, 288, 384])
# torch.Size([1, 288, 384])
# (np.float64(-0.5), np.float64(383.5), np.float64(287.5), np.float64(-0.5))
